# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# <h1 style="text-align: center;">Deep Learning<br><br>Assignment-1 (ANN)<br><br>Churn Prediction for Bank Customer<br><h1>

# %% [markdown]
# # Dataset Info

# %% [markdown]
# We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.
#
# The features in the given dataset are:
# - **rownumber:** Row Numbers from 1 to 10000.
# - **customerid:** A unique ID that identifies each customer.
# - **surname:** The customer’s surname.
# - **creditscore:** A credit score is a number between 300–850 that depicts a consumer's creditworthiness.
# - **geography:** The country from which the customer belongs to.
# - **Gender:** The customer’s gender: Male, Female
# - **Age:** The customer’s current age, in years, at the time of being customer.
# - **tenure:** The number of years for which the customer has been with the bank.
# - **balance:** Bank balance of the customer.
# - **numofproducts:** the number of bank products the customer is utilising.
# - **hascrcard:** The number of credit cards given to the customer by the bank.
# - **isactivemember:** Binary Flag for indicating if the client is active or not with the bank before the moment where the client exits the company (recorded in the variable "exited")
# - **exited:** Binary flag 1 if the customer closed account with bank and 0 if the customer is retained.

# %% [markdown]
# # Improt Libraries & Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (8,5)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %% [markdown]
# 1. Implement basic steps to see how is your data looks like
# 2. Check for missing values
# 3. Drop the features that not suitable for modelling
# 4. Implement basic visualization steps such as histogram, countplot, heatmap
# 5. Convert categorical variables to dummy variables

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.000              1          1               1
# 1       1  83807.860              1          0               1
# 2       8 159660.800              3          1               0
# 3       1      0.000              2          0               0
# 4       2 125510.820              1          1               1
#
#    EstimatedSalary  Exited
# 0       101348.880       1
# 1       112542.580       0
# 2       113931.570       1
# 3        93826.630       0
# 4        79084.100       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5      0.000              2          1               0
# 9996      10  57369.610              1          1               1
# 9997       7      0.000              1          0               1
# 9998       3  75075.310              2          1               0
# 9999       4 130142.790              1          1               0
#
#       EstimatedSalary  Exited
# 9995        96270.640       0
# 9996       101699.770       0
# 9997        42085.580       1
# 9998        92888.520       1
# 9999        38190.780       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#pip install skimpy

# %%
from skimpy import clean_columns

# %%
df = clean_columns(df)
# Out:
# 14 column names have been cleaned

# %%
df.columns
# Out:
# Index(['row_number', 'customer_id', 'surname', 'credit_score', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'num_of_products', 'has_cr_card',
#        'is_active_member', 'estimated_salary', 'exited'],
#       dtype='object')

# %%
df.head()
# Out:
#    row_number  customer_id   surname  credit_score geography  gender  age  \
# 0           1     15634602  Hargrave           619    France  Female   42
# 1           2     15647311      Hill           608     Spain  Female   41
# 2           3     15619304      Onio           502    France  Female   42
# 3           4     15701354      Boni           699    France  Female   39
# 4           5     15737888  Mitchell           850     Spain  Female   43
#
#    tenure    balance  num_of_products  has_cr_card  is_active_member  \
# 0       2      0.000                1            1                 1
# 1       1  83807.860                1            0                 1
# 2       8 159660.800                3            1                 0
# 3       1      0.000                2            0                 0
# 4       2 125510.820                1            1                 1
#
#    estimated_salary  exited
# 0        101348.880       1
# 1        112542.580       0
# 2        113931.570       1
# 3         93826.630       0
# 4         79084.100       0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# row_number          10000
# customer_id         10000
# surname              2932
# credit_score          460
# geography               3
# gender                  2
# age                    70
# tenure                 11
# balance              6382
# num_of_products         4
# has_cr_card             2
# is_active_member        2
# estimated_salary     9999
# exited                  2
# dtype: int64

# %%
df.describe().T
# Out:
#                      count         mean       std          min          25%  \
# row_number       10000.000     5000.500  2886.896        1.000     2500.750
# customer_id      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# credit_score     10000.000      650.529    96.653      350.000      584.000
# age              10000.000       38.922    10.488       18.000       32.000
# tenure           10000.000        5.013     2.892        0.000        3.000
# balance          10000.000    76485.889 62397.405        0.000        0.000
# num_of_products  10000.000        1.530     0.582        1.000        1.000
# has_cr_card      10000.000        0.706     0.456        0.000        0.000
# is_active_member 10000.000        0.515     0.500        0.000        0.000
# estimated_salary 10000.000   100090.240 57510.493       11.580    51002.110
# exited           10000.000        0.204     0.403        0.000        0.000
#
#                           50%          75%          max
# row_number           5000.500     7500.250    10000.000
# customer_id      15690738.000 15753233.750 15815690.000
# credit_score          652.000      718.000      850.000
# age                    37.000       44.000       92.000
# tenure                  5.000        7.000       10.000
# balance             97198.540   127644.240   250898.090
# num_of_products         1.000        2.000        4.000
# has_cr_card             1.000        1.000        1.000
# is_active_member        1.000        1.000        1.000
# estimated_salary   100193.915   149388.247   199992.480
# exited                  0.000        0.000        1.000

# %%
df.describe(include="O").T
# Out:
#            count unique     top  freq
# surname    10000   2932   Smith    32
# geography  10000      3  France  5014
# gender     10000      2    Male  5457

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## geography / gender

# %%
df.geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: geography, dtype: int64

# %%
df.gender.value_counts()
# Out:
# Male      5457
# Female    4543
# Name: gender, dtype: int64

# %%
df.replace({"gender":{"Male":0, "Female":1}, "geography":{"France":0, "Germany":1, "Spain":2}}, inplace=True)

# %%
df.gender.value_counts()
# Out:
# 0    5457
# 1    4543
# Name: gender, dtype: int64

# %%
df.geography.value_counts()
# Out:
# 0    5014
# 1    2509
# 2    2477
# Name: geography, dtype: int64

# %%
df.has_cr_card.value_counts()
# Out:
# 1    7055
# 0    2945
# Name: has_cr_card, dtype: int64

# %%
drop_list = ["row_number", "customer_id", "surname"]

# %%
df.drop(columns=drop_list, inplace=True)

# %%
df.head()
# Out:
#    credit_score  geography  gender  age  tenure    balance  num_of_products  \
# 0           619          0       1   42       2      0.000                1
# 1           608          2       1   41       1  83807.860                1
# 2           502          0       1   42       8 159660.800                3
# 3           699          0       1   39       1      0.000                2
# 4           850          2       1   43       2 125510.820                1
#
#    has_cr_card  is_active_member  estimated_salary  exited
# 0            1                 1        101348.880       1
# 1            0                 1        112542.580       0
# 2            1                 0        113931.570       1
# 3            0                 0         93826.630       0
# 4            1                 1         79084.100       0

# %%
ax = sns.countplot(data=df, x="exited");

for i in ax.containers:
    ax.bar_label(i, fmt="%.1f");

# %%
df.hist(figsize=(15, 12), bins=15);

# %%
plt.figure(figsize=(20, 7))
sns.distplot(df.age);

# %%
sns.histplot(data = df, x = "age", hue = "exited", fill=True);

# %%
sns.kdeplot(data = df, x = "age", hue = "exited", fill=True);

# %%
plt.figure(figsize=(15, 7))
sns.countplot(data=df, x="age", hue=df.exited);

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(df.corr(), annot=True, cmap='viridis');

# %%
df.corr()['exited'][:-1].sort_values().plot.barh();

# %% [markdown]
# # Preprocessing of Data
# - Train | Test Split, Scalling

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
seed = 42

# %%
X = df.drop("exited", axis=1)
y = df["exited"]

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed
)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (9000, 10)
# Train target shape   :  (9000,)
# Test features shape  :  (1000, 10)
# Test target shape    :  (1000,)

# %% [markdown]
# # Modelling & Model Performance

# %% [markdown]
# ## without class_weigth

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(32, activation="relu", input_dim = X_train.shape[1]))
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

opt = Adam(lr=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %% [markdown]
# ### Create The Model

# %%
model.fit(x=X_train, y=y_train, validation_split=.1, batch_size=100, epochs=300, verbose=1)
# Out:
# Epoch 1/300
# 81/81 [==============================] - 2s 6ms/step - loss: 0.5536 - recall: 0.0278 - val_loss: 0.4933 - val_recall: 0.0000e+00
# Epoch 2/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4924 - recall: 0.0000e+00 - val_loss: 0.4740 - val_recall: 0.0000e+00
# Epoch 3/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.4746 - recall: 0.0000e+00 - val_loss: 0.4520 - val_recall: 0.0000e+00
# Epoch 4/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4566 - recall: 0.0285 - val_loss: 0.4314 - val_recall: 0.1326
# Epoch 5/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4437 - recall: 0.1162 - val_loss: 0.4175 - val_recall: 0.1436
# Epoch 6/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4336 - recall: 0.1447 - val_loss: 0.4077 - val_recall: 0.1492
# Epoch 7/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4254 - recall: 0.1828 - val_loss: 0.3966 - val_recall: 0.2928
# Epoch 8/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4162 - recall: 0.1919 - val_loss: 0.3864 - val_recall: 0.2762
# Epoch 9/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.4056 - recall: 0.2385 - val_loss: 0.3730 - val_recall: 0.3757
# Epoch 10/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3976 - recall: 0.2669 - val_loss: 0.3588 - val_recall: 0.2928
# Epoch 11/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3886 - recall: 0.3087 - val_loss: 0.3557 - val_recall: 0.5249
# Epoch 12/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3810 - recall: 0.3590 - val_loss: 0.3362 - val_recall: 0.4309
# Epoch 13/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3726 - recall: 0.3826 - val_loss: 0.3307 - val_recall: 0.5635
# Epoch 14/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3697 - recall: 0.3862 - val_loss: 0.3203 - val_recall: 0.4420
# Epoch 15/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3650 - recall: 0.4038 - val_loss: 0.3155 - val_recall: 0.4751
# Epoch 16/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3625 - recall: 0.4050 - val_loss: 0.3141 - val_recall: 0.5304
# Epoch 17/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3604 - recall: 0.4110 - val_loss: 0.3136 - val_recall: 0.4530
# Epoch 18/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3597 - recall: 0.4074 - val_loss: 0.3116 - val_recall: 0.4862
# Epoch 19/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3582 - recall: 0.4104 - val_loss: 0.3123 - val_recall: 0.5691
# Epoch 20/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3582 - recall: 0.4177 - val_loss: 0.3094 - val_recall: 0.4972
# Epoch 21/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3561 - recall: 0.4038 - val_loss: 0.3102 - val_recall: 0.4972
# Epoch 22/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3546 - recall: 0.4159 - val_loss: 0.3063 - val_recall: 0.5138
# Epoch 23/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3545 - recall: 0.4219 - val_loss: 0.3037 - val_recall: 0.5028
# Epoch 24/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3550 - recall: 0.4165 - val_loss: 0.3075 - val_recall: 0.5304
# Epoch 25/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3527 - recall: 0.4274 - val_loss: 0.3067 - val_recall: 0.4751
# Epoch 26/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3519 - recall: 0.4177 - val_loss: 0.3053 - val_recall: 0.5028
# Epoch 27/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3518 - recall: 0.4280 - val_loss: 0.3086 - val_recall: 0.5801
# Epoch 28/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3545 - recall: 0.4177 - val_loss: 0.3058 - val_recall: 0.5635
# Epoch 29/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3499 - recall: 0.4153 - val_loss: 0.3051 - val_recall: 0.5525
# Epoch 30/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3495 - recall: 0.4316 - val_loss: 0.3014 - val_recall: 0.5635
# Epoch 31/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3505 - recall: 0.4231 - val_loss: 0.3020 - val_recall: 0.4917
# Epoch 32/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3485 - recall: 0.4274 - val_loss: 0.3007 - val_recall: 0.5083
# Epoch 33/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3479 - recall: 0.4292 - val_loss: 0.3009 - val_recall: 0.4862
# Epoch 34/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3482 - recall: 0.4237 - val_loss: 0.2977 - val_recall: 0.5249
# Epoch 35/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3483 - recall: 0.4364 - val_loss: 0.3003 - val_recall: 0.5083
# Epoch 36/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3468 - recall: 0.4243 - val_loss: 0.2970 - val_recall: 0.5083
# Epoch 37/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3488 - recall: 0.4189 - val_loss: 0.2998 - val_recall: 0.5304
# Epoch 38/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3477 - recall: 0.4249 - val_loss: 0.3014 - val_recall: 0.5359
# Epoch 39/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3451 - recall: 0.4310 - val_loss: 0.2970 - val_recall: 0.4972
# Epoch 40/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3455 - recall: 0.4328 - val_loss: 0.2997 - val_recall: 0.5083
# Epoch 41/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3443 - recall: 0.4237 - val_loss: 0.2991 - val_recall: 0.5304
# Epoch 42/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3452 - recall: 0.4377 - val_loss: 0.3028 - val_recall: 0.4586
# Epoch 43/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3438 - recall: 0.4310 - val_loss: 0.2969 - val_recall: 0.5414
# Epoch 44/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3451 - recall: 0.4280 - val_loss: 0.2991 - val_recall: 0.4862
# Epoch 45/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3432 - recall: 0.4352 - val_loss: 0.2989 - val_recall: 0.5028
# Epoch 46/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3436 - recall: 0.4243 - val_loss: 0.2988 - val_recall: 0.5249
# Epoch 47/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3425 - recall: 0.4443 - val_loss: 0.2979 - val_recall: 0.4972
# Epoch 48/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3437 - recall: 0.4249 - val_loss: 0.2979 - val_recall: 0.4862
# Epoch 49/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3413 - recall: 0.4377 - val_loss: 0.3019 - val_recall: 0.4586
# Epoch 50/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3417 - recall: 0.4346 - val_loss: 0.2982 - val_recall: 0.5249
# Epoch 51/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3415 - recall: 0.4389 - val_loss: 0.2976 - val_recall: 0.5138
# Epoch 52/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3402 - recall: 0.4401 - val_loss: 0.3057 - val_recall: 0.6133
# Epoch 53/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3409 - recall: 0.4473 - val_loss: 0.2960 - val_recall: 0.5138
# Epoch 54/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3395 - recall: 0.4340 - val_loss: 0.2948 - val_recall: 0.5249
# Epoch 55/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3400 - recall: 0.4413 - val_loss: 0.2979 - val_recall: 0.5138
# Epoch 56/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3399 - recall: 0.4510 - val_loss: 0.3008 - val_recall: 0.4972
# Epoch 57/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3409 - recall: 0.4370 - val_loss: 0.2971 - val_recall: 0.5470
# Epoch 58/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.
300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3171 - recall: 0.4988 - val_loss: 0.2988 - val_recall: 0.5470
# Epoch 193/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3174 - recall: 0.5036 - val_loss: 0.2973 - val_recall: 0.5470
# Epoch 194/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3171 - recall: 0.4903 - val_loss: 0.2977 - val_recall: 0.5580
# Epoch 195/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3161 - recall: 0.4964 - val_loss: 0.3021 - val_recall: 0.5304
# Epoch 196/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3183 - recall: 0.5079 - val_loss: 0.2981 - val_recall: 0.5470
# Epoch 197/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3170 - recall: 0.5012 - val_loss: 0.3025 - val_recall: 0.5470
# Epoch 198/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3139 - recall: 0.5073 - val_loss: 0.2988 - val_recall: 0.5525
# Epoch 199/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3174 - recall: 0.5030 - val_loss: 0.2987 - val_recall: 0.5635
# Epoch 200/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3154 - recall: 0.5103 - val_loss: 0.2973 - val_recall: 0.5691
# Epoch 201/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3162 - recall: 0.4909 - val_loss: 0.3083 - val_recall: 0.6188
# Epoch 202/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3142 - recall: 0.5006 - val_loss: 0.3016 - val_recall: 0.5193
# Epoch 203/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3147 - recall: 0.5000 - val_loss: 0.2994 - val_recall: 0.4917
# Epoch 204/300
# 81/81 [==============================] - 0s 6ms/step - loss: 0.3145 - recall: 0.5018 - val_loss: 0.3012 - val_recall: 0.5083
# Epoch 205/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3168 - recall: 0.5018 - val_loss: 0.2987 - val_recall: 0.5414
# Epoch 206/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3156 - recall: 0.4933 - val_loss: 0.2982 - val_recall: 0.5083
# Epoch 207/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3143 - recall: 0.5097 - val_loss: 0.3000 - val_recall: 0.5967
# Epoch 208/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3134 - recall: 0.5115 - val_loss: 0.3019 - val_recall: 0.5083
# Epoch 209/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3135 - recall: 0.5067 - val_loss: 0.3067 - val_recall: 0.4807
# Epoch 210/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3147 - recall: 0.5061 - val_loss: 0.3029 - val_recall: 0.5083
# Epoch 211/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3163 - recall: 0.5006 - val_loss: 0.3039 - val_recall: 0.5746
# Epoch 212/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3132 - recall: 0.5048 - val_loss: 0.3073 - val_recall: 0.6188
# Epoch 213/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3133 - recall: 0.5024 - val_loss: 0.2981 - val_recall: 0.6022
# Epoch 214/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3146 - recall: 0.5115 - val_loss: 0.3086 - val_recall: 0.4862
# Epoch 215/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3139 - recall: 0.5024 - val_loss: 0.3013 - val_recall: 0.5028
# Epoch 216/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3133 - recall: 0.5103 - val_loss: 0.3047 - val_recall: 0.5414
# Epoch 217/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3138 - recall: 0.4994 - val_loss: 0.3026 - val_recall: 0.4917
# Epoch 218/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3144 - recall: 0.5042 - val_loss: 0.2987 - val_recall: 0.5414
# Epoch 219/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3144 - recall: 0.5151 - val_loss: 0.2975 - val_recall: 0.5746
# Epoch 220/300
# 81/81 [==============================] - 0s 6ms/step - loss: 0.3160 - recall: 0.5103 - val_loss: 0.3084 - val_recall: 0.5856
# Epoch 221/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3125 - recall: 0.5176 - val_loss: 0.3020 - val_recall: 0.4972
# Epoch 222/300
# 81/81 [==============================] - 0s 6ms/step - loss: 0.3128 - recall: 0.5073 - val_loss: 0.3054 - val_recall: 0.5359
# Epoch 223/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3127 - recall: 0.5121 - val_loss: 0.3009 - val_recall: 0.5414
# Epoch 224/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3129 - recall: 0.5151 - val_loss: 0.2994 - val_recall: 0.5028
# Epoch 225/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3145 - recall: 0.5103 - val_loss: 0.3038 - val_recall: 0.5083
# Epoch 226/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3129 - recall: 0.5097 - val_loss: 0.3006 - val_recall: 0.5138
# Epoch 227/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3140 - recall: 0.5097 - val_loss: 0.3003 - val_recall: 0.5470
# Epoch 228/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3126 - recall: 0.5115 - val_loss: 0.3047 - val_recall: 0.4972
# Epoch 229/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3122 - recall: 0.5103 - val_loss: 0.3015 - val_recall: 0.5580
# Epoch 230/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3144 - recall: 0.5103 - val_loss: 0.3040 - val_recall: 0.4917
# Epoch 231/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3136 - recall: 0.5061 - val_loss: 0.3026 - val_recall: 0.5691
# Epoch 232/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3126 - recall: 0.5230 - val_loss: 0.2998 - val_recall: 0.5580
# Epoch 233/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3118 - recall: 0.5042 - val_loss: 0.2979 - val_recall: 0.6133
# Epoch 234/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3124 - recall: 0.5139 - val_loss: 0.3024 - val_recall: 0.6022
# Epoch 235/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3119 - recall: 0.5169 - val_loss: 0.2992 - val_recall: 0.5414
# Epoch 236/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3122 - recall: 0.5042 - val_loss: 0.3015 - val_recall: 0.5304
# Epoch 237/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3101 - recall: 0.5133 - val_loss: 0.3016 - val_recall: 0.4751
# Epoch 238/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3143 - recall: 0.5054 - val_loss: 0.3001 - val_recall: 0.5967
# Epoch 239/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3113 - recall: 0.5188 - val_loss: 0.3011 - val_recall: 0.5193
# Epoch 240/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3124 - recall: 0.5054 - val_loss: 0.2995 - val_recall: 0.5414
# Epoch 241/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3110 - recall: 0.5151 - val_loss: 0.2992 - val_recall: 0.5138
# Epoch 242/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3130 - recall: 0.5103 - val_loss: 0.3080 - val_recall: 0.4586
# Epoch 243/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3123 - recall: 0.5042 - val_loss: 0.2974 - val_recall: 0.5525
# Epoch 244/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3099 - recall: 0.5176 - val_loss: 0.3076 - val_recall: 0.5414
# Epoch 245/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3118 - recall: 0.5182 - val_loss: 0.2980 - val_recall: 0.5912
# Epoch 246/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3117 - recall: 0.5206 - val_loss: 0.3017 - val_recall: 0.5138
# Epoch 247/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3104 - recall: 0.5097 - val_loss: 0.2983 - val_recall: 0.5912
# Epoch 248/300
# 81/81 [==============================] - 0s 6ms/step - loss: 0.3107 - recall: 0.5169 - val_loss: 0.3025 - val_recall: 0.5083
# Epoch 249/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3119 - recall: 0.5054 - val_loss: 0.3024 - val_recall: 0.5580
# Epoch 250/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3102 - recall: 0.5121 - val_loss: 0.3015 - val_recall: 0.5635
# Epoch 251/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3103 - recall: 0.5163 - val_loss: 0.3018 - val_recall: 0.5856
# Epoch 252/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3146 - recall: 0.5121 - val_loss: 0.3050 - val_recall: 0.5414
# Epoch 253/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3121 - recall: 0.5157 - val_loss: 0.3032 - val_recall: 0.5691
# Epoch 254/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3123 - recall: 0.5145 - val_loss: 0.3063 - val_recall: 0.5967
# Epoch 255/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3122 - recall: 0.5176 - val_loss: 0.3054 - val_recall: 0.6022
# Epoch 256/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3106 - recall: 0.5182 - val_loss: 0.3034 - val_recall: 0.5801
# Epoch 257/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3105 - recall: 0.5121 - val_loss: 0.3034 - val_recall: 0.5414
# Epoch 258/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3097 - recall: 0.5182 - val_loss: 0.3025 - val_recall: 0.5470
# Epoch 259/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3101 - recall: 0.5145 - val_loss: 0.3042 - val_recall: 0.5083
# Epoch 260/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3102 - recall: 0.5236 - val_loss: 0.3029 - val_recall: 0.4751
# Epoch 261/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3124 - recall: 0.5218 - val_loss: 0.3037 - val_recall: 0.5249
# Epoch 262/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3117 - recall: 0.5012 - val_loss: 0.3073 - val_recall: 0.4807
# Epoch 263/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3098 - recall: 0.5157 - val_loss: 0.3028 - val_recall: 0.5138
# Epoch 264/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3092 - recall: 0.5169 - val_loss: 0.2998 - val_recall: 0.5691
# Epoch 265/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3095 - recall: 0.5139 - val_loss: 0.3041 - val_recall: 0.5746
# Epoch 266/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3097 - recall: 0.5067 - val_loss: 0.3160 - val_recall: 0.6464
# Epoch 267/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3113 - recall: 0.5157 - val_loss: 0.3045 - val_recall: 0.5359
# Epoch 268/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3087 - recall: 0.5206 - val_loss: 0.3017 - val_recall: 0.5028
# Epoch 269/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3102 - recall: 0.5176 - val_loss: 0.3045 - val_recall: 0.4862
# Epoch 270/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3100 - recall: 0.4994 - val_loss: 0.3156 - val_recall: 0.6409
# Epoch 271/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3102 - recall: 0.5248 - val_loss: 0.3021 - val_recall: 0.5525
# Epoch 272/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3086 - recall: 0.5163 - val_loss: 0.2991 - val_recall: 0.5691
# Epoch 273/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3100 - recall: 0.5067 - val_loss: 0.3055 - val_recall: 0.5691
# Epoch 274/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3103 - recall: 0.5188 - val_loss: 0.3026 - val_recall: 0.5967
# Epoch 275/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3090 - recall: 0.5091 - val_loss: 0.3047 - val_recall: 0.5359
# Epoch 276/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3085 - recall: 0.5163 - val_loss: 0.3020 - val_recall: 0.5470
# Epoch 277/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3106 - recall: 0.5188 - val_loss: 0.3017 - val_recall: 0.5635
# Epoch 278/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3093 - recall: 0.5145 - val_loss: 0.3020 - val_recall: 0.5691
# Epoch 279/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3114 - recall: 0.5073 - val_loss: 0.3067 - val_recall: 0.5801
# Epoch 280/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3107 - recall: 0.5230 - val_loss: 0.3065 - val_recall: 0.4917
# Epoch 281/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3089 - recall: 0.5109 - val_loss: 0.3001 - val_recall: 0.5470
# Epoch 282/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3078 - recall: 0.5254 - val_loss: 0.3091 - val_recall: 0.5193
# Epoch 283/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3106 - recall: 0.5145 - val_loss: 0.3072 - val_recall: 0.5414
# Epoch 284/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3095 - recall: 0.5091 - val_loss: 0.3027 - val_recall: 0.5138
# Epoch 285/300
# 81/81 [==============================] - 1s 7ms/step - loss: 0.3081 - recall: 0.5266 - val_loss: 0.3064 - val_recall: 0.4807
# Epoch 286/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3083 - recall: 0.5085 - val_loss: 0.3038 - val_recall: 0.6022
# Epoch 287/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3087 - recall: 0.5230 - val_loss: 0.3098 - val_recall: 0.4862
# Epoch 288/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3086 - recall: 0.5230 - val_loss: 0.3045 - val_recall: 0.5635
# Epoch 289/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3074 - recall: 0.5194 - val_loss: 0.3020 - val_recall: 0.5967
# Epoch 290/300
# 81/81 [==============================] - 0s 5ms/step - loss: 0.3093 - recall: 0.5103 - val_loss: 0.3070 - val_recall: 0.6354
# Epoch 291/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3089 - recall: 0.5285 - val_loss: 0.3038 - val_recall: 0.5028
# Epoch 292/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3102 - recall: 0.5048 - val_loss: 0.3125 - val_recall: 0.5635
# Epoch 293/300
# 81/81 [==============================] - 0s 4ms/step - loss: 0.3089 - recall: 0.5230 - val_loss: 0.3074 - val_recall: 0.5414
# Epoch 294/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3080 - recall: 0.5163 - val_loss: 0.2994 - val_recall: 0.5414
# Epoch 295/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3087 - recall: 0.5212 - val_loss: 0.3068 - val_recall: 0.5083
# Epoch 296/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3069 - recall: 0.5121 - val_loss: 0.3002 - val_recall: 0.5801
# Epoch 297/300
# 81/81 [==============================] - 0s 3ms/step - loss: 0.3080 - recall: 0.5115 - val_loss: 0.3041 - val_recall: 0.5801
# Epoch 298/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3085 - recall: 0.5188 - val_loss: 0.3063 - val_recall: 0.5304
# Epoch 299/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3073 - recall: 0.5315 - val_loss: 0.2992 - val_recall: 0.5193
# Epoch 300/300
# 81/81 [==============================] - 0s 2ms/step - loss: 0.3066 - recall: 0.5224 - val_loss: 0.3059 - val_recall: 0.5470

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                352
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.3490142822265625, 0.46078431606292725]

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.3490142822265625
# accuracy :  0.46078431606292725

# %%
y_pred = model.predict(X_test) > 0.5

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 [==============================] - 1s 3ms/step
# [[763  33]
#  [110  94]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       796
#            1       0.74      0.46      0.57       204
#
#     accuracy                           0.86      1000
#    macro avg       0.81      0.71      0.74      1000
# weighted avg       0.85      0.86      0.84      1000

# %% [markdown]
# ### Precision-Recall Curve and AP (Average Precision) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6789355159303986

# %% [markdown]
# ## with class_weigth
#
# Investigate how the "class_weight" hyper-parameter is used in a Neural Network.

# %% [markdown]
# ### Create The Model

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %% [markdown]
# ## Implementation Different Methods to Develop The Model
#
# - Implement the following methods on model creating with "class_weight" parameter
# - Create and evaluate model for each method

# %% [markdown]
# ### Increase The Learning Rate and Observe The Results

# %% [markdown]
# ### Add Dropout Layer

# %% [markdown]
# ### Add Early Stop

# %% [markdown]
# #### Monitor the "val_loss" as metric

# %% [markdown]
# #### Monitor the "val_recall" as metric

# %% [markdown]
# ## GridSearchCV

# %% [markdown]
# ### Evaluate The Model
#
# - Plot the model history to observe the changing of metrics
# - Make prediction to see "confusion matrix" and "classification report"
# - Check ROC (Receiver Operating Curve) and AUC (Area Under Curve) for the model

# %% [markdown]
# # Final Model and Model Deployment

# %% [markdown]
# ## Prediction

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
